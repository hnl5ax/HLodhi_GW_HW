# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x97a4518>,
#   <matplotlib.axis.XTick at 0x91874e0>,
#   <matplotlib.axis.XTick at 0x8dd8240>,
#   <matplotlib.axis.XTick at 0x9835438>,
#   <matplotlib.axis.XTick at 0x9835940>,
#   <matplotlib.axis.XTick at 0x9835eb8>,
#   <matplotlib.axis.XTick at 0x983c470>,
#   <matplotlib.axis.XTick at 0x983c9e8>,
#   <matplotlib.axis.XTick at 0x983cf60>,
#   <matplotlib.axis.XTick at 0x983c3c8>,
#   <matplotlib.axis.XTick at 0x98357b8>,
#   <matplotlib.axis.XTick at 0x9843828>,
#   <matplotlib.axis.XTick at 0x9843da0>,
#   <matplotlib.axis.XTick at 0x9849358>,
#   <matplotlib.axis.XTick at 0x98498d0>,
#   <matplotlib.axis.XTick at 0x9849e48>,
#   <matplotlib.axis.XTick at 0x9851400>,
#   <matplotlib.axis.XTick at 0x9851978>,
#   <matplotlib.axis.XTick at 0x9851ef0>,
#   <matplotlib.axis.XTick at 0x9851a58>,
#   <matplotlib.axis.XTick at 0x9849978>,
#   <matplotlib.axis.XTick at 0x98593c8>,
#   <matplotlib.axis.XTick at 0x9859940>,
#   <matplotlib.axis.XTick at 0x9859eb8>,
#   <matplotlib.axis.XTick at 0x9861470>,
#   <matplotlib.axis.XTick at 0x98619e8>,
#   <matplotlib.axis.XTick at 0x9861f60>,
#   <matplotlib.axis.XTick at 0x9867518>,
#   <matplotlib.axis.XTick at 0x98613c8>,
#   <matplotlib.axis.XTick at 0x98597b8>,
#   <matplotlib.axis.XTick at 0x98676d8>,
#   <matplotlib.axis.XTick at 0x9867e80>,
#   <matplotlib.axis.XTick at 0x986f550>,
#   <matplotlib.axis.XTick at 0x986fac8>,
#   <matplotlib.axis.XTick at 0x98760f0>,
#   <matplotlib.axis.XTick at 0x98765f8>,
#   <matplotlib.axis.XTick at 0x9876b70>,
#   <matplotlib.axis.XTick at 0x987d160>,
#   <matplotlib.axis.XTick at 0x98769e8>,
#   <matplotlib.axis.XTick at 0x9867da0>,
#   <matplotlib.axis.XTick at 0x987d5c0>,
#   <matplotlib.axis.XTick at 0x987db38>,
#   <matplotlib.axis.XTick at 0x9883160>,
#   <matplotlib.axis.XTick at 0x9883668>,
#   <matplotlib.axis.XTick at 0x9883be0>,
#   <matplotlib.axis.XTick at 0x988b198>,
#   <matplotlib.axis.XTick at 0x988b710>,
#   <matplotlib.axis.XTick at 0x9883470>,
#   <matplotlib.axis.XTick at 0x987dc18>,
#   <matplotlib.axis.XTick at 0x98435c0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images")
plt.show()
